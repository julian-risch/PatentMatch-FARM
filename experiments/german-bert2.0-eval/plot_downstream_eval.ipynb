# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("phase_2_part_1.csv")

# %%
df['steps_k'] = df["Name"].str.split("_").apply(lambda x: int(x[1].replace("step",""))/1000)
df['task'] = df["Name"].str.split("_").apply(lambda x: x[0])

# %%
grouped = df.groupby(by=("steps_k", "task")).mean()
# Out:
# /Users/deepset/deepset/environments/main3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   """Entry point for launching an IPython kernel.

# %%
ge18_coarse = df.loc[df["task"] == "germEval18Coarse"]
ge18_fine = df.loc[df["task"] == "germEval18Fine"]
ge14 = df.loc[df["task"] == "germEval14"]

# %%
def plot(task_df, y="Test_f1_macro_text_classification"):
    task_df = task_df.sort_values(by="steps_k")
    grouped = task_df.groupby(by="steps_k").mean().reset_index()
#     grouped.plot(kind="line", x="steps_k", y=y)
    sns.relplot(x="steps_k", y=y, kind="line", data=task_df)

# %%
plot(ge18_coarse, "Test_f1_macro_text_classification")
plot(ge18_fine, "Test_f1_macro_text_classification")
plot(ge14, "Test_seq_f1_ner")

# %%
df
# Out:
#                               Run ID                           Name  \
# 0   e30a3e39bd784752891c760d8efa8013  germEval18Coarse_step300000_0
# 1   ae8aaeaad7014889bbf35e65473025fd    germEval18Fine_step300000_4
# 2   09acf1885599474cb00b215266fc9f92    germEval18Fine_step300000_3
# 3   e44cd02fb43b42298165a571bb8a8222    germEval18Fine_step300000_2
# 4   81cdc190598845e39d7495a998c69475    germEval18Fine_step300000_1
# ..                               ...                            ...
# 91  e52bc991a5a34428bc6bfaac920fd032    germEval18Fine_step900000_4
# 92  514c7912752d4d25923e4bd1a32bc7d1    germEval18Fine_step900000_3
# 93  31715acdb92e4844967ed9b8dacc1bfa    germEval18Fine_step900000_2
# 94  6f385e521bc8402d871149fa46dd9f81    germEval18Fine_step900000_1
# 95  ca407b63341a45a6895c003efbc3e038    germEval18Fine_step900000_0
#
#    Source Type Source Name    User    Status  \
# 0        LOCAL     eval.py  ubuntu   RUNNING
# 1        LOCAL     eval.py  ubuntu  FINISHED
# ...
